-- %%
CREATE TABLE DEV.demo.EMP (ID INT, NAME STRING);

-- %%
ALTER TABLE DEV.demo.EMP ADD COLUMNS (
  ID INT,
  NAME STRING
);

-- %%
INSERT INTO DEV.demo.EMP VALUES (1, 'NAVAL'), (2, 'MAHESH'), (3, 'REVATI');

-- %%
DESC EXTENDED DEV.demo.EMP;

-- %%
ALTER TABLE DEV.demo.EMP SET TBLPROPERTIES (
  'delta.columnMapping.mode' = 'name'
);

ALTER TABLE DEV.demo.EMP DROP COLUMNS (col1, col2);

-- %%
DESC EXTENDED DEV.demo.EMP;

-- %%
DESC DETAIL DEV.demo.EMP;

-- %%
DESC HISTORY DEV.DEMO.EMP;
