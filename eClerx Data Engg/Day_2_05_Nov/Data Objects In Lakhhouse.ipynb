-- %% [markdown]
-- DATABRICKS ARCHITECH

-- %% [markdown]
-- ![](/Volumes/dev/demo/row/architecture-c2c83d23e2f7870f30137e97aaadea0b.png)

-- %% [markdown]
-- Catalog
-- Schema/ Databases
-- Tables/Views/volume/functions, model/Store Procedure
--
--
-- 1.UI
-- 2.sql syntex

-- %%
%sql
CREATE CATALOG IF NOT EXISTS dev;
use catalog dev;

create schema demo;

-- %%
%sql
CREATE TABLE if not exists dev.demo.sample
(
  id INT ,name STRING);

-- %%
%sql insert into dev.demo.sample values(1, 'Naval'), (2, 'Dhaval') ,(3, 'Chahal');

-- %%
%sql
Select * from dev.demo.sample;

-- %% [markdown]
-- **CTAS (CREATE TABLE AS SELECT)**
-- FOR CREATE A TABLE FROM EXISTING TABLE
-- EX- CREATE TABLE (LOCATION WHERE TO STORE) AS SELECT * FORM (TABLE NAME)
--
--
-- **CREATE OR REPLACE TABLE=> TRUNCATE AND LOAD FRESH DATA**
-- EX- CREATE OR REPLACE TABLE (LOCATION WHERE TO STORE) AS SELECT * FROM (TABLE NAME)

-- %%
%sql
SELECT * FROM samples.bakehouse.sales_transactions;

-- %%
CREATE TABLE dev.demo.sales_transactions AS

SELECT * FROM samples.bakehouse.sales_transactions
