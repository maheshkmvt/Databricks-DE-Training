# %% [markdown]
# Method 1: PySpark
#
# DataFrame
#
# https://spark.apache.org/docs/latest/api/python/reference/index.html

# %%
# %python
df=spark.read.csv("/Volumes/dev/demo/row/INPUT DATA/financial_dataset.csv") 

df=spark.read.csv("/Volumes/dev/demo/row/INPUT DATA/financial_dataset.csv",header=True,inferSchema=True)

# %%
df.display()

# %%
df.write.mode("overwrite").saveAsTable("dev.demo.financial_pyspark")

# %%
df.display()
