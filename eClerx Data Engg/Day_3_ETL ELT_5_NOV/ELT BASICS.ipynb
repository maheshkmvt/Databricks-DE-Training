-- %% [markdown]
-- WAYS TO CREATE A TABLES
-- -PYSPARK
-- -SPARK SQL
--    1 SELECT * FROM FILE_FORMAT.`PATH` (SINGLE LINE JSON, PARQUET,DELTA,ICEBURG,CSV,MULTI LINE JSON, XML)
-- -UI (LIMITED)

-- %%
SELECT * FROM JSON.`/Volumes/dev/demo/row/INPUT DATA/retail_orders.json`

-- %%
--create table dev.demo.customer as  


SELECT * FROM PARQUET.`/Volumes/dev/demo/row/INPUT DATA/part-00000-4ece8039-e05f-4114-8262-9d82c9ee1e62-c000.snappy.parquet`

-- %% [markdown]
-- Method - 2 Spark SQL

-- %%
SELECT * FROM read_files("/Volumes/dev/demo/row/INPUT DATA/financial_dataset.csv",FORMAT =>"CSV")

-- %%
CREATE TABLE dev.demo.finacial_dataset AS
SELECT * FROM read_files("/Volumes/dev/demo/row/INPUT DATA/financial_dataset.csv",FORMAT =>"CSV")

-- %%
select * from dev.demo.finacial_dataset;

-- %%
select * from csv.`/Volumes/dev/demo/row/INPUT DATA/financial_dataset.csv`

-- %%
Select * from read_files("/Volumes/dev/demo/row/INPUT DATA/part-00000-4ece8039-e05f-4114-8262-9d82c9ee1e62-c000.snappy.parquet",format =>"parquet")

-- %%
SELECT * FROM read_files("/Volumes/dev/demo/row/INPUT DATA/retail_orders.json", format => "json")
